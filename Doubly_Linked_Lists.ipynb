# %% [markdown]
# ### **Traversal Operation**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
    
class DoublyLL:
    def __init__(self):
        self.head = None
    
    def print_forward(self):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , end = " ")
                n = n.nref
                
    def print_backward(self):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,end = " ")
                n = n.pref
                
LL = DoublyLL()
LL.print_forward()
# Out:
# Linked Lists is empty

# %% [markdown]
# ### **Insertion in Doubly Linked Lists**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
    
class Doubly_LL:
    def __init__(self):
        self.head = None
        
    def print_forward(self):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , end = " ")
                n = n.nref
                
    def print_backward(self):
        print()
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data , end = " ")
                n = n.pref
                
    def insert_empty(self,data):
        if self.head is None:
            new_node = Node(data)
            self.head = new_node
        else:
            print("Linked Lists is not empty")
    
            
    def add_begin(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref = self.head
            self.head.pref = new_node
            self.head = new_node
            
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref = new_node
            new_node.pref = n
  
LL = Doubly_LL()
LL.insert_empty(30)
LL.add_begin(20)
LL.add_begin(10)
LL.add_end(40)
LL.print_forward()
LL.print_backward()
# Out:
# 10 20 30 40
# 40
# 40 30 20 10

# %% [markdown]
# ### **Insertion in between nodes of a doubly LL**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class DoublyLL:
    def __init__(self):
        self.head = None
        
    def print_forward(self):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data,end = " ")
                n = n.nref
                
    def print_backward(self):
        print()
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,end = " ")
                n = n.pref
                
    def add_begin(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref = self.head
            self.head.pref = new_node
            self.head = new_node
            
    def add_end(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.nref = new_node
            new_node.pref = n
            
    def add_after(self,data,x):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present")
            else:
                new_node = Node(data)
                new_node.nref = n.nref
                new_node.pref = n
                if n.nref is not None:
                    n.nref.pref = new_node
                n.nref = new_node
                
    def add_before(self,data,x):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n is not None:
                if x == n.data:
                    break
                n = n.nref
            if n is None:
                print("Given node is not present")
            else:
                new_node = Node(data)
                new_node.nref = n
                if n.pref is not None:
                    n.pref.nref = new_node
                else:
                    self.head = new_node
                n.pref = new_node
     
LL = DoublyLL()
LL.add_begin(40)
LL.add_begin(20)
LL.add_before(10,20)
LL.add_after(30,20)
LL.print_forward()
LL.print_backward()
# Out:
# 10 20 30 40
# 40 30 20 10

# %% [markdown]
# ### **Deletion operation in Doubly LL**

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.nref = None
        self.pref = None
        
class DoublyLL:
    def __init__(self):
        self.head = None
    def print_forward(self):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n is not None:
                print(n.data , end = " ")
                n = n.nref
            
    def print_backward(self):
        print()
        if self.head is None:
            print("Linked Lists is empty")
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            while n is not None:
                print(n.data,end = " ")
                n = n.pref
                
    def add_begin(self,data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.nref = self.head
            self.head.pref = new_node
            self.head = new_node
            
    def delete_begin(self):
        if self.head is None:
            print("Linked Lists is empty")
        else:
            if self.head.nref is None:
                self.head = None
            else:
                self.head = self.head.nref
                self.head.pref = None
                
    def delete_end(self):
        if self.head is None:
            print("Linked Lists is empty")
        if self.head.nref is None:
            self.head = None
        else:
            n = self.head
            while n.nref is not None:
                n = n.nref
            n.pref.nref = None
            
    def delete_by_value(self,x):
        if self.head is None:
            print("Linked Lists is empty")
        if self.head.nref is None:
            if x == self.data:
                self.head = None
            else:
                print("Given node is not present in Linked Lists")
        if self.head.data == x:
            self.head = self.head.nref
            self.head.pref = None
        n = self.head
        while n.nref is not None:
            if x == n.data:
                break
            n = n.nref
            
        if n.nref is not None:
            n.pref.nref = n.nref
            n.nref.pref = n.pref
        else:
            if n.data == x:
                n.pref.nref = None
            else:
                print("Given node is not present in Linked Lists")
                
                
LL = DoublyLL()
LL.add_begin(50)
LL.add_begin(40)
LL.add_begin(30)
LL.add_begin(20)
LL.add_begin(10)
LL.delete_begin()
LL.delete_end()
LL.delete_by_value(30)
LL.print_forward()
LL.print_backward()
# Out:
# 20 40
# 40 20
